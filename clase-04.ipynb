# %% [markdown]
# # Clase #4

# %%
import sys
sys.dont_write_bytecode = True

import math
import numpy as np
import cv2 as cv
import lib.image_utils as ImgUtils
# %matplotlib inline

import contextlib
with contextlib.redirect_stdout(None):
    np.seterr(divide = 'ignore')

# %%
image = cv.imread('./images/im10-1.jpg', cv.IMREAD_GRAYSCALE)
ImgUtils.imshow2(
    image,
    ImgUtils.transform(
        image,
        ImgUtils.create_kernel(size = 3, value = 1 / 9)
    ),
)

# %%
image2 = cv.imread('./images/im12-1.jpg', cv.IMREAD_GRAYSCALE)
ImgUtils.imshow2(
    image2,
    ImgUtils.median_transform(image2, kern_size = 5),
)

# %%
image3 = cv.imread('./images/im11-1.jpg', cv.IMREAD_GRAYSCALE)
ImgUtils.imshow2(
    image3,
    ImgUtils.transform(
        image3,
        ImgUtils.create_gaussian_kernel()
    ),
    ImgUtils.transform(
        image3,
        ImgUtils.create_gaussian_kernel(size = 5)
    ),
    ImgUtils.transform(
        image3,
        ImgUtils.create_gaussian_kernel(size = 17)
    ),
    ImgUtils.transform(
        image3,
        ImgUtils.create_gaussian_kernel(size = 17, sig = 8)
    ),
    cols = 5
)
