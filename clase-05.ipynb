# %% [markdown]
# # Clase #5

# %%
import sys
sys.dont_write_bytecode = True

import math
import numpy as np
import cv2 as cv
import lib.image_utils as ImgUtils
# %matplotlib inline

import contextlib
with contextlib.redirect_stdout(None):
    np.seterr(divide = 'ignore')

# %%
image = cv.imread('./images/im11-1.jpg', cv.IMREAD_GRAYSCALE)
ImgUtils.imshow2(
    image,
    cv.blur(image, (3, 3)),
    cv.blur(image, (5, 5)),
    cv.blur(image, (15, 15)),
    cols = 5
)

# %%
image2 = cv.imread('./images/im12-1.jpg', cv.IMREAD_GRAYSCALE)
ImgUtils.imshow2(
    image2,
    cv.medianBlur(image2, ksize = 3),
    cv.medianBlur(image2, ksize = 5),
    cv.medianBlur(image2, ksize = 9),
    cols = 5
)
